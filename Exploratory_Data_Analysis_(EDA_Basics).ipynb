# %% [markdown]
# <a href="https://colab.research.google.com/github/gaurav-0022/Assignment-1/blob/main/Exploratory_Data_Analysis_(EDA_Basics).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-19c1f5dd-602e-4bc1-af8e-d23b1bcaf42f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-19c1f5dd-602e-4bc1-af8e-d23b1bcaf42f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('House Price India.csv')

# Display first rows
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
df.fillna(df.median(numeric_only=True), inplace=True)

# %% [markdown]
# ##Q1. What is the average, median, and standard deviation of house prices?

# %%
avg_price = df['Price'].mean()
median_price = df['Price'].median()
std_price = df['Price'].std()

avg_price, median_price, std_price
# Out:
# (np.float64(538932.2183310534), 450000.0, 367532.3808039669)

# %% [markdown]
# ##Q2. Which number of bedrooms is most common?

# %%
df['number of bedrooms'].mode()
# Out:
# 0    3
# Name: number of bedrooms, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %% [markdown]
# ##Q3. Check if the price data is skewed.

# %%
df['Price'].skew()
# Out:
# np.float64(4.269297720707116)

# %%
sns.histplot(df['Price'], kde=True)
plt.show()

# %% [markdown]
# ##Q4. What is the average price for each number of bedrooms?

# %%
df.groupby('number of bedrooms')['Price'].mean()
# Out:
# number of bedrooms
# 1     3.089638e+05
# 2     3.985476e+05
# 3     4.632776e+05
# 4     6.361988e+05
# 5     7.752550e+05
# 6     8.375815e+05
# 7     1.016544e+06
# 8     1.208455e+06
# 9     7.766663e+05
# 10    8.200000e+05
# 11    5.200000e+05
# 33    6.400000e+05
# Name: Price, dtype: float64

# %% [markdown]
# ##Q5.  What is the relationship between living area and price? (Use : Area without Basement).

# %%
sns.scatterplot(x=df['living area'], y=df['Price'])
plt.show()

df[['living area', 'Price']].corr()
# Out:
#              living area     Price
# living area     1.000000  0.712169
# Price           0.712169  1.000000

# %% [markdown]
# ##Q6. Identify any anomalies where houses have high prices but low areas

# %%
threshold_price = df['Price'].quantile(0.90)
threshold_area = df['living area'].quantile(0.10)

anomalies = df[(df['Price'] > threshold_price) & (df['living area'] < threshold_area)]
anomalies
# Out:
# Empty DataFrame
# Columns: [id, Date, number of bedrooms, number of bathrooms, living area, lot area, number of floors, waterfront present, number of views, condition of the house, grade of the house, Area of the house(excluding basement), Area of the basement, Built Year, Renovation Year, Postal Code, Lattitude, Longitude, living_area_renov, lot_area_renov, Number of schools nearby, Distance from the airport, Price]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# ##Q7. Compare average price based on number of floors and houses with or without waterfront

# %%
df.groupby(['number of floors', 'waterfront present'])['Price'].mean()
# Out:
# number of floors  waterfront present
# 1.0               0                     4.323724e+05
#                   1                     1.211081e+06
# 1.5               0                     5.476162e+05
#                   1                     1.232507e+06
# 2.0               0                     6.357742e+05
#                   1                     2.075931e+06
# 2.5               0                     1.087654e+06
#                   1                     3.280000e+06
# 3.0               0                     5.558095e+05
#                   1                     1.655000e+06
# 3.5               0                     1.205875e+06
# Name: Price, dtype: float64

# %% [markdown]
# ##Q8. Identify the minimum and maximum house price. What does this indicate?

# %%
min_price = df['Price'].min()
max_price = df['Price'].max()

min_price, max_price
# Out:
# (78000, 7700000)

# %% [markdown]
# ##Q9. Which location (zipcode/area) has the highest average price?

# %%
df.groupby('Postal Code')['Price'].mean().sort_values(ascending=False).head()
# Out:
# Postal Code
# 122071    2.348311e+06
# 122048    1.296414e+06
# 122057    1.188517e+06
# 122047    1.069295e+06
# 122061    8.895896e+05
# Name: Price, dtype: float64

# %% [markdown]
# ##Q10. Write at least 5 insights from your analysis.

# %% [markdown]
# ## Example Insights:
# 1 House prices are right-skewed, meaning a few luxury houses increase the average.
#
# 2 Most houses have 2–3 bedrooms, showing common buyer preference.
#
# 3 Price has a strong positive correlation with living area.
#
# 4 Waterfront properties are significantly more expensive.
#
# 5 Certain zipcodes dominate in price, indicating premium areas.
#
# 6 Some small houses have very high prices, likely due to location advantages.
#
# 7 Increasing bedrooms generally increases price, but not always linearly.
