# %% [markdown]
# <a href="https://colab.research.google.com/github/gaurav-0022/Assignment-1/blob/main/Libraries_NumPy_%26_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fb6e3ff9-0ced-4fac-802d-8f64d26ffc37" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb6e3ff9-0ced-4fac-802d-8f64d26ffc37">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Q1. Load the given retail sales dataset into a Pandas DataFrame and display the first 5 rows along with the dataset information to understand its structure.

# %%
# Load dataset
df = pd.read_csv('retail_dataset .csv')

# Display first 5 rows
print("First 5 Rows:")
display(df.head())

# Display dataset info
print("\nDataset Info:")
df.info()
# Out:
# First 5 Rows:
#   Transaction ID Customer ID Product Category  Quantity   Price        Date  \
# 0           T001        C015            Books       7.0   167.0  02-02-2023
# 1           T002        C004             Toys       4.0   374.0  17-02-2023
# 2           T003        C033        Furniture       8.0  1059.0  17-05-2024
# 3           T004        C047        Groceries       5.0   304.0  11-02-2024
# 4           T005        C022            Books       7.0   282.0  27-07-2024
#
#   Region
# 0  North
# 1  South
# 2  South
# 3  South
# 4   West
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    100 non-null    object
#  1   Customer ID       100 non-null    object
#  2   Product Category  97 non-null     object
#  3   Quantity          98 non-null     float64
# ...

# %% [markdown]
# ## Q2. Inspect the dataset and identify missing values in each column. Display the total number of missing values present in the dataset.

# %%
# Missing values per column
print("Missing Values per Column:")
print(df.isnull().sum())

# Total missing values
total_missing = df.isnull().sum().sum()
print("\nTotal Missing Values:", total_missing)
# Out:
# Missing Values per Column:
# Transaction ID      0
# Customer ID         0
# Product Category    3
# Quantity            2
# Price               5
# Date                0
# Region              2
# dtype: int64
#
# Total Missing Values: 12

# %% [markdown]
# ##Q3. Replace missing values in the Quantity and Price columns with their respective mean values using Pandas.

# %%
# Replace missing values with mean
df['Quantity'].fillna(df['Quantity'].mean(), inplace=True)
df['Price'].fillna(df['Price'].mean(), inplace=True)

print("Missing values after replacement:")
print(df[['Quantity', 'Price']].isnull().sum())
# Out:
# Missing values after replacement:
# Quantity    0
# Price       0
# dtype: int64
# /tmp/ipykernel_20499/2115256791.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Quantity'].fillna(df['Quantity'].mean(), inplace=True)
# /tmp/ipykernel_20499/2115256791.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ##Q4. Remove all rows where the Product Category or Region column contains missing values.

# %%
# Drop rows with missing Product Category or Region
df.dropna(subset=['Product Category', 'Region'], inplace=True)

print("Dataset shape after removing rows:", df.shape)
# Out:
# Dataset shape after removing rows: (95, 7)

# %% [markdown]
# ##Q5. Create a new column called Revenue using NumPy, where:
#
# Revenue = Quantity × Price
#
# Display the updated dataset with the new column.

# %%
# Create Revenue column
df['Revenue'] = np.multiply(df['Quantity'], df['Price'])

# Display updated dataset
display(df.head())
# Out:
#   Transaction ID Customer ID Product Category  Quantity   Price        Date  \
# 0           T001        C015            Books       7.0   167.0  02-02-2023
# 1           T002        C004             Toys       4.0   374.0  17-02-2023
# 2           T003        C033        Furniture       8.0  1059.0  17-05-2024
# 3           T004        C047        Groceries       5.0   304.0  11-02-2024
# 4           T005        C022            Books       7.0   282.0  27-07-2024
#
#   Region  Revenue
# 0  North   1169.0
# 1  South   1496.0
# 2  South   8472.0
# 3  South   1520.0
# 4   West   1974.0

# %% [markdown]
# ##Q6. Using NumPy, calculate the total revenue generated from all transactions in the dataset.

# %%
total_revenue = np.sum(df['Revenue'])
print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 465529.66058002145

# %% [markdown]
# ##Q7. Group the dataset by Product Category and calculate the total revenue generated by each category.

# %%
category_revenue = df.groupby('Product Category')['Revenue'].sum()

print("Revenue by Product Category:")
print(category_revenue)
# Out:
# Revenue by Product Category:
# Product Category
# Beauty          27647.000000
# Books           29597.938776
# Clothing        85006.000000
# Electronics     93204.315789
# Furniture      129664.526316
# Groceries       11978.000000
# Sports          34484.000000
# Toys            53947.879699
# Name: Revenue, dtype: float64

# %% [markdown]
# ##Q8. Based on the revenue calculated for each product category, identify the top 3 categories with the highest revenue and the bottom 3 categories with the lowest revenue.

# %%
# Top 3 categories
top3 = category_revenue.sort_values(ascending=False).head(3)

# Bottom 3 categories
bottom3 = category_revenue.sort_values().head(3)

print("Top 3 Categories:\n", top3)
print("\nBottom 3 Categories:\n", bottom3)
# Out:
# Top 3 Categories:
#  Product Category
# Furniture      129664.526316
# Electronics     93204.315789
# Clothing        85006.000000
# Name: Revenue, dtype: float64
#
# Bottom 3 Categories:
#  Product Category
# Groceries    11978.000000
# Beauty       27647.000000
# Books        29597.938776
# Name: Revenue, dtype: float64

# %% [markdown]
# ##Q9. Group the dataset by Region and calculate the total revenue generated in each region. Identify the region with the highest revenue and the region with the lowest revenue.

# %%
region_revenue = df.groupby('Region')['Revenue'].sum()

print("Revenue by Region:")
print(region_revenue)

# Highest and lowest
highest_region = region_revenue.idxmax()
lowest_region = region_revenue.idxmin()

print("\nHighest Revenue Region:", highest_region)
print("Lowest Revenue Region:", lowest_region)
# Out:
# Revenue by Region:
# Region
# East     126232.044039
# North    153244.353383
# South    104855.736842
# West      81197.526316
# Name: Revenue, dtype: float64
#
# Highest Revenue Region: North
# Lowest Revenue Region: West

# %% [markdown]
# ##Q10. Extract the month from the Date column using Pandas and group the dataset by month to calculate the total monthly revenue. Also, calculate the mean, median, and standard deviation of the Revenue column using NumPy.

# %%
# Convert Date column safely
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# Check if conversion worked
print(df['Date'].head())

# Extract month
df['Month'] = df['Date'].dt.month

# Monthly revenue
monthly_revenue = df.groupby('Month')['Revenue'].sum()

print("Monthly Revenue:")
print(monthly_revenue)

# NumPy statistics
import numpy as np

mean_rev = np.mean(df['Revenue'])
median_rev = np.median(df['Revenue'])
std_rev = np.std(df['Revenue'])

print("\nRevenue Statistics:")
print("Mean:", mean_rev)
print("Median:", median_rev)
print("Standard Deviation:", std_rev)
# Out:
# 0   2023-02-02
# 1          NaT
# 2          NaT
# 3   2024-11-02
# 4          NaT
# Name: Date, dtype: datetime64[ns]
# Monthly Revenue:
# Month
# 1.0      2240.000000
# 2.0     13945.000000
# 3.0      3220.000000
# 4.0      9146.105263
# 5.0      5355.000000
# 6.0     16400.000000
# 7.0     24083.938776
# 8.0     34491.000000
# 9.0     16479.210526
# 10.0    39939.142857
# 11.0    11747.000000
# 12.0    13072.736842
# Name: Revenue, dtype: float64
#
# Revenue Statistics:
# Mean: 4900.312216631804
# Median: 3282.1052631578946
# Standard Deviation: 4721.171795257337
